# %%
! pip install langchain==0.1.14 openai==1.14.3 langchain-openai==0.1.1
! pip install pypdf
! pip install langchain-chroma

# %%
# 독서모임 플로우 수정 버전
from langchain.document_loaders import PyPDFLoader
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain.chains import RetrievalQA
from langchain.chat_models import ChatOpenAI
import time


class RAGBookClubGPT:
    def __init__(self, pdf_path, api_key):
        """
        RAG 기반 독서 모임 AI 초기화
        pdf_path: 독서 모임 관련 PDF 문서 경로
        api_key: OpenAI API 키
        """

        # 데이터 로드
        loader = PyPDFLoader(pdf_path)
        self.docs = loader.load()

        # 벡터 임베딩 생성 및 데이터베이스 구축
        embeddings_model = OpenAIEmbeddings(api_key=api_key)
        self.db = Chroma.from_documents(self.docs, embeddings_model)

        # 데이터 검색기 및 QA 체인 초기화
        self.retriever = self.db.as_retriever()
        self.llm = ChatOpenAI(model_name="gpt-4", api_key=api_key)
        self.qa_chain = RetrievalQA.from_chain_type(
            llm=self.llm,
            chain_type="stuff",
            retriever=self.retriever
        )

    def generate_topics(self, user_responses):
        """
        RAG 기반으로 발제문 생성
        user_responses: 참가자 감상문
        """

        system_message = "Generate three non-political, open-ended discussion topics in Korean based on this book. The topics must end with a sentence."
        user_message = "\n".join(user_responses)

        # RAG 기반 문맥 검색 및 발제문 생성
        context_docs = self.retriever.get_relevant_documents("발제문 생성에 필요한 주요 내용")
        context_text = "\n".join(doc.page_content for doc in context_docs)

        prompt = f"{system_message}\n\nPDF 문서 내용:\n{context_text}\n\n참가자 감상문:\n{user_message}"
        response = self.llm.predict(prompt)

        # 발제문 나누기 및 공백 제거
        topics = [topic.strip() for topic in response.split("\n") if topic.strip()]
        if len(topics) < 3:
            print("⚠️ 발제문 생성에 실패했습니다. 출력을 확인하세요.")
            print(response)
            return []

        print("선정된 발제문:")
        for topic in topics:
            print(f"- {topic}")

        return topics

    def collect_responses(self, topic):
        """
        주어진 주제에 대해 참가자들의 의견을 수집하고, 욕설 및 비방 내용을 필터링하는 메서드
        """

        print(f'\n주제: {topic}')
        print('이 주제에 대해 의견을 작성해 주세요.')

        responses = []
        while True:
            user_input = input("사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): ").strip()
            if user_input.lower() == "종료":
                break

            try:
                user, response = user_input.split(":", 1)
                responses.append(f"{user.strip()}: {response.strip()}")
            except ValueError:
                print("잘못된 입력 형식입니다. '사용자명: 의견' 형식으로 입력해주세요.")

        filtered_responses = self.filter_responses(responses)
        print('필터링된 의견:')
        for response in filtered_responses:
            print(response)

        return filtered_responses

    def filter_responses(self, responses):
        """
        참가자들의 응답에서 욕설이나 비방이 포함된 내용을 필터링하는 메서드.
        """

        bad_words = ['욕설', '비방']
        filtered = [response for response in responses if not any(bad_word in response for bad_word in bad_words)]
        return filtered


    def facilitate_free_discussion(self, opinion, time_limit=10):
        """
        특정 의견에 대한 자유 토의를 제한 시간 동안 진행
        opinion: 논의 중심이 될 사용자 의견
        time_limit: 제한 시간(초 단위)
        """
        # 테스트를 위해 test_limit = 10으로 설정. 원래는 180
        print(f"💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요")
        start_time = time.time()

        while True:
            elapsed_time = time.time() - start_time
            remaining_time = time_limit - elapsed_time

            if remaining_time <= 0:
                print("\n⏳ 자유토의 시간이 종료되었습니다.")
                break

            print(f"⏱️ 남은 시간: {int(remaining_time)}초", end="\r")
            time.sleep(1)

        print("다음 의견으로 넘어갑니다.")

    def summarize_meeting(self, topics, all_responses):
        """
        RAG 기반으로 모임 내용을 요약하는 메서드
        topics: 논의된 주제들
        all_responses: 참가자들의 모든 응답
        """

        print('\n모임 내용을 요약합니다...')
        summary_prompt = "다음은 독서 모임에서 논의된 내용입니다. 각 주제에 대해 요약을 작성해줘.:\n"

        for i, topic in enumerate(topics):
            summary_prompt += f"주제 {i + 1}: {topic}\n응답:\n" + "\n".join(all_responses[i]) + "\n"

        response = self.llm.predict(summary_prompt)
        summary = response.strip()

        print("모임 요약:")
        print(summary)

    def run_meeting(self, user_responses):
        """
        전체 독서 모임 흐름 실행
        """

        topics = self.generate_topics(user_responses)
        if not topics:
            print("모임을 시작할 수 없습니다. 발제문을 생성하지 못했습니다.")
            return

        all_responses = []
        for topic in topics:
            responses = self.collect_responses(topic)
            all_responses.append(responses)

            for opinion in responses:
                print(f"현재 의견: {opinion}")
                self.facilitate_free_discussion(opinion, time_limit=10) # 테스트를 위해 10초로 설정

        self.summarize_meeting(topics, all_responses)

# %%
# PDF 경로와 OpenAI API 키 입력
pdf_path = "/content/1984.pdf"  # PDF 파일 경로
api_key = "##API key 입력##"  # OpenAI API 키

# RAGBookClubGPT 인스턴스 생성
rag_book_club = RAGBookClubGPT(pdf_path, api_key)

# 사용자 감상문 입력 (예시)
user_responses = [
  "사용자1: 1984는 인간의 자유와 권리가 어떻게 억압될 수 있는지를 극명하게 보여주는 작품입니다. 소설 속에서 '빅 브라더'라는 상징적인 존재는 모든 시민을 감시하고 통제하며, 개인의 사생활을 철저히 침해합니다. 이러한 설정은 현대 사회에서도 점점 강화되고 있는 감시 기술과 프라이버시 침해 문제를 떠올리게 합니다. 특히, 정부나 기업이 개인의 데이터를 수집하고 이를 활용하는 방식은 소설 속 감시 체제와 유사한 점이 많습니다. 오웰은 이러한 미래를 경고하며, 독자로 하여금 자유와 권리를 지키기 위해 경각심을 갖도록 촉구합니다. 이 작품은 기술 발전이 가져올 수 있는 부정적인 측면을 경계하게 만들며, 개인의 자유가 얼마나 소중한지를 일깨워 줍니다.",
  "사용자2: 조지 오웰의 1984는 전체주의 체제의 위험성을 경고하는 강력한 메시지를 담고 있습니다. 소설 속 당은 과거를 조작하고, 언어를 통제하며, 개인의 사고까지 지배하려 합니다. 이는 비판적 사고가 억압될 때 사회가 얼마나 쉽게 무너질 수 있는지를 보여줍니다. 주인공 윈스턴 스미스는 체제에 저항하려 하지만, 결국 당의 압도적인 힘 앞에서 무력함을 느끼게 됩니다. 이는 독재 체제 하에서 인간성이 어떻게 파괴될 수 있는지를 생생하게 전달합니다. 오웰은 독자들에게 비판적 사고와 자유로운 의사 표현이 얼마나 중요한지를 상기시키며, 이러한 가치들이 억압될 때 사회가 어떤 방향으로 나아갈 수 있는지를 경고합니다.",
  "사용자3: 오웰의 1984는 인간 본성에 대한 깊은 통찰을 제공합니다. 윈스턴 스미스는 사랑과 자유를 추구하지만, 결국 체제에 굴복하게 됩니다. 이는 인간의 본성과 욕망이 어떻게 억압될 수 있는지를 보여줍니다. 소설은 독자로 하여금 개인의 자유와 인간성을 지키기 위해 끊임없이 노력해야 한다는 메시지를 전달합니다. 특히, 사랑과 우정 같은 인간적 유대가 어떻게 체제에 의해 파괴될 수 있는지를 통해 인간성 상실의 위험성을 경고합니다. 이는 오늘날에도 여전히 중요한 교훈으로 남아 있으며, 개인이 자신의 정체성과 가치를 지키기 위해 어떤 노력을 해야 하는지를 고민하게 만듭니다.",
  "사용자4: 흥미로웠습니다. 디스토피아 소설의 원조답게 재밌게 잘 읽었습니다. 현재와도 맞닿아 있는 부분이 많아서 작가의 통찰력이 대단하다는 생각이 들었습니다."
  ]

# 독서 모임 실행
rag_book_club.run_meeting(user_responses)
# Out:
# 선정된 발제문:
# - 1. "1984"에서 조지 오웰은 개인의 사생활이 철저히 침해되는 상황을 묘사하고 있습니다. 이와 같은 상황이 현대 사회에서도 벌어지고 있다고 생각하시나요? 그렇다면 그 예는 무엇인가요?
# - 2. "1984"는 전체주의 체제에서 비판적 사고가 억압될 때 사회가 어떻게 쉽게 무너질 수 있는지 보여줍니다. 현대 사회에서 비판적 사고를 억압하는 경우를 본 적이 있나요? 만약 있다면 그 사례는 무엇인가요?
# - 3. 소설에서는 사랑과 우정 같은 인간적 유대가 체제에 의해 파괴되는 모습을 보여줍니다. 현실에서는 어떤 경우에 이런 상황이 벌어질 수 있을까요? 이에 대한 여러분의 생각은 어떠한가요?
#
# 주제: 1. "1984"에서 조지 오웰은 개인의 사생활이 철저히 침해되는 상황을 묘사하고 있습니다. 이와 같은 상황이 현대 사회에서도 벌어지고 있다고 생각하시나요? 그렇다면 그 예는 무엇인가요?
# 이 주제에 대해 의견을 작성해 주세요.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 1984에서 빅 브라더는 텔레스크린을 통해 시민들을 감시합니다. 이는 현대 사회에서 스마트폰, CCTV, 인터넷 기기들이 개인의 활동을 추적하는 방식과 유사합니다. 예를 들어, 스마트폰의 위치 추적 기능이나 인터넷 사용 기록은 개인의 일상생활을 감시할 수 있는 도구로 활용됩니다15. 이러한 기술 발전은 편리함을 제공하는 동시에 사생활 침해의 위험을 증가시킵니다.
# 잘못된 입력 형식입니다. '사용자명: 의견' 형식으로 입력해주세요.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자1: 1984에서 빅 브라더는 텔레스크린을 통해 시민들을 감시합니다. 이는 현대 사회에서 스마트폰, CCTV, 인터넷 기기들이 개인의 활동을 추적하는 방식과 유사합니다. 예를 들어, 스마트폰의 위치 추적 기능이나 인터넷 사용 기록은 개인의 일상생활을 감시할 수 있는 도구로 활용됩니다15. 이러한 기술 발전은 편리함을 제공하는 동시에 사생활 침해의 위험을 증가시킵니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자2: 현대 사회에서는 다양한 온라인 플랫폼과 서비스가 사용자 데이터를 수집하고 이를 분석하여 상업적 목적으로 활용합니다. 이는 1984에서 정부가 개인 정보를 통제하고 조작하는 방식과 유사합니다. 최근 발생한 여러 데이터 유출 사건들은 개인 정보가 얼마나 쉽게 노출될 수 있는지를 보여주며3, 우리는 데이터 보호와 프라이버시 권리에 대한 경각심을 가져야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자3: AI와 안면 인식 기술은 공공장소에서 사람들을 식별하고 추적할 수 있게 하며, 이는 1984의 사상 경찰과 비슷한 역할을 합니다24. 이러한 기술은 범죄 예방에 도움을 줄 수 있지만, 동시에 개인의 자유를 제한하고 차별적인 결과를 초래할 수 있습니다. 우리는 AI 기술이 공정하고 투명하게 사용되도록 규제와 감독이 필요합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자4: 1984에서는 정부가 정보를 통제하고 왜곡하여 시민들의 사고를 제한합니다. 현대 사회에서도 가짜 뉴스와 정보 조작이 여론 형성에 영향을 미치고 있으며, 이는 표현의 자유를 위협합니다2. 우리는 다양한 정보에 접근하고 비판적으로 사고할 수 있는 환경을 조성하여 이러한 위험에 대응해야 합니다. 이러한 논의는 현대 사회가 직면한 프라이버시와 감시 문제를 이해하고, 이를 해결하기 위한 방안을 모색하는 데 중요한 시사점을 제공합니다. 우리는 기술 발전이 가져오는 이점과 위험을 균형 있게 고려해야 하며, 개인의 자유와 프라이버시를 보호하기 위한 노력을 지속해야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 종료
# 필터링된 의견:
# 사용자1: 1984에서 빅 브라더는 텔레스크린을 통해 시민들을 감시합니다. 이는 현대 사회에서 스마트폰, CCTV, 인터넷 기기들이 개인의 활동을 추적하는 방식과 유사합니다. 예를 들어, 스마트폰의 위치 추적 기능이나 인터넷 사용 기록은 개인의 일상생활을 감시할 수 있는 도구로 활용됩니다15. 이러한 기술 발전은 편리함을 제공하는 동시에 사생활 침해의 위험을 증가시킵니다.
# 사용자2: 현대 사회에서는 다양한 온라인 플랫폼과 서비스가 사용자 데이터를 수집하고 이를 분석하여 상업적 목적으로 활용합니다. 이는 1984에서 정부가 개인 정보를 통제하고 조작하는 방식과 유사합니다. 최근 발생한 여러 데이터 유출 사건들은 개인 정보가 얼마나 쉽게 노출될 수 있는지를 보여주며3, 우리는 데이터 보호와 프라이버시 권리에 대한 경각심을 가져야 합니다.
# 사용자3: AI와 안면 인식 기술은 공공장소에서 사람들을 식별하고 추적할 수 있게 하며, 이는 1984의 사상 경찰과 비슷한 역할을 합니다24. 이러한 기술은 범죄 예방에 도움을 줄 수 있지만, 동시에 개인의 자유를 제한하고 차별적인 결과를 초래할 수 있습니다. 우리는 AI 기술이 공정하고 투명하게 사용되도록 규제와 감독이 필요합니다.
# 사용자4: 1984에서는 정부가 정보를 통제하고 왜곡하여 시민들의 사고를 제한합니다. 현대 사회에서도 가짜 뉴스와 정보 조작이 여론 형성에 영향을 미치고 있으며, 이는 표현의 자유를 위협합니다2. 우리는 다양한 정보에 접근하고 비판적으로 사고할 수 있는 환경을 조성하여 이러한 위험에 대응해야 합니다. 이러한 논의는 현대 사회가 직면한 프라이버시와 감시 문제를 이해하고, 이를 해결하기 위한 방안을 모색하는 데 중요한 시사점을 제공합니다. 우리는 기술 발전이 가져오는 이점과 위험을 균형 있게 고려해야 하며, 개인의 자유와 프라이버시를 보호하기 위한 노력을 지속해야 합니다.
# 현재 의견: 사용자1: 1984에서 빅 브라더는 텔레스크린을 통해 시민들을 감시합니다. 이는 현대 사회에서 스마트폰, CCTV, 인터넷 기기들이 개인의 활동을 추적하는 방식과 유사합니다. 예를 들어, 스마트폰의 위치 추적 기능이나 인터넷 사용 기록은 개인의 일상생활을 감시할 수 있는 도구로 활용됩니다15. 이러한 기술 발전은 편리함을 제공하는 동시에 사생활 침해의 위험을 증가시킵니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자2: 현대 사회에서는 다양한 온라인 플랫폼과 서비스가 사용자 데이터를 수집하고 이를 분석하여 상업적 목적으로 활용합니다. 이는 1984에서 정부가 개인 정보를 통제하고 조작하는 방식과 유사합니다. 최근 발생한 여러 데이터 유출 사건들은 개인 정보가 얼마나 쉽게 노출될 수 있는지를 보여주며3, 우리는 데이터 보호와 프라이버시 권리에 대한 경각심을 가져야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자3: AI와 안면 인식 기술은 공공장소에서 사람들을 식별하고 추적할 수 있게 하며, 이는 1984의 사상 경찰과 비슷한 역할을 합니다24. 이러한 기술은 범죄 예방에 도움을 줄 수 있지만, 동시에 개인의 자유를 제한하고 차별적인 결과를 초래할 수 있습니다. 우리는 AI 기술이 공정하고 투명하게 사용되도록 규제와 감독이 필요합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자4: 1984에서는 정부가 정보를 통제하고 왜곡하여 시민들의 사고를 제한합니다. 현대 사회에서도 가짜 뉴스와 정보 조작이 여론 형성에 영향을 미치고 있으며, 이는 표현의 자유를 위협합니다2. 우리는 다양한 정보에 접근하고 비판적으로 사고할 수 있는 환경을 조성하여 이러한 위험에 대응해야 합니다. 이러한 논의는 현대 사회가 직면한 프라이버시와 감시 문제를 이해하고, 이를 해결하기 위한 방안을 모색하는 데 중요한 시사점을 제공합니다. 우리는 기술 발전이 가져오는 이점과 위험을 균형 있게 고려해야 하며, 개인의 자유와 프라이버시를 보호하기 위한 노력을 지속해야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
#
# 주제: 2. "1984"는 전체주의 체제에서 비판적 사고가 억압될 때 사회가 어떻게 쉽게 무너질 수 있는지 보여줍니다. 현대 사회에서 비판적 사고를 억압하는 경우를 본 적이 있나요? 만약 있다면 그 사례는 무엇인가요?
# 이 주제에 대해 의견을 작성해 주세요.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자1: 미국의 일부 주에서는 학교에서 인종, 성별, 성적 지향 등과 관련된 비판적 관점을 가르치는 것을 제한하는 정책이 시행되고 있습니다1. 이러한 검열은 학생들이 다양한 시각을 접하고 비판적으로 사고할 기회를 박탈하며, 이는 교육의 본질을 훼손합니다. 교육은 다양한 관점을 통해 학생들이 스스로 사고할 수 있도록 도와야 하며, 검열은 이러한 과정을 방해합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자2: 현대 교육 시스템에서는 표준화된 시험과 결과 중심의 교육이 강조되면서, 학생들의 비판적 사고 능력이 저해되고 있습니다3. 시험 준비에 집중하다 보면 창의적이고 비판적인 사고를 할 기회가 줄어들며, 이는 학생들이 사회 문제를 깊이 있게 이해하고 해결할 능력을 제한합니다. 교육은 단순한 지식 전달이 아닌, 학생들이 비판적으로 사고하고 문제를 해결할 수 있는 능력을 길러줘야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자3: 책과 자료에 대한 검열은 독자들의 비판적 사고를 저해합니다2. 특정 주제나 관점을 담고 있는 책이 금지되거나 제한될 때, 독자들은 다양한 시각을 접할 기회를 잃게 됩니다. 이는 사회가 복잡한 문제를 이해하고 해결하는 데 필요한 능력을 약화시킵니다. 우리는 다양한 정보를 자유롭게 접할 수 있는 환경을 조성해야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자4: 일부 국가에서는 정부가 미디어와 표현의 자유를 억압하여 특정 관점만을 허용하는 경우가 있습니다. 이는 시민들이 다양한 정보를 접하고 비판적으로 사고할 기회를 제한합니다. 이러한 억압은 사회 전반에 걸쳐 창의성과 혁신을 저해하며, 장기적으로는 사회 발전을 방해합니다. 우리는 표현의 자유를 보호하고 다양한 목소리가 공존할 수 있는 사회를 만들어야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 종료
# 필터링된 의견:
# 사용자1: 미국의 일부 주에서는 학교에서 인종, 성별, 성적 지향 등과 관련된 비판적 관점을 가르치는 것을 제한하는 정책이 시행되고 있습니다1. 이러한 검열은 학생들이 다양한 시각을 접하고 비판적으로 사고할 기회를 박탈하며, 이는 교육의 본질을 훼손합니다. 교육은 다양한 관점을 통해 학생들이 스스로 사고할 수 있도록 도와야 하며, 검열은 이러한 과정을 방해합니다.
# 사용자2: 현대 교육 시스템에서는 표준화된 시험과 결과 중심의 교육이 강조되면서, 학생들의 비판적 사고 능력이 저해되고 있습니다3. 시험 준비에 집중하다 보면 창의적이고 비판적인 사고를 할 기회가 줄어들며, 이는 학생들이 사회 문제를 깊이 있게 이해하고 해결할 능력을 제한합니다. 교육은 단순한 지식 전달이 아닌, 학생들이 비판적으로 사고하고 문제를 해결할 수 있는 능력을 길러줘야 합니다.
# 사용자3: 책과 자료에 대한 검열은 독자들의 비판적 사고를 저해합니다2. 특정 주제나 관점을 담고 있는 책이 금지되거나 제한될 때, 독자들은 다양한 시각을 접할 기회를 잃게 됩니다. 이는 사회가 복잡한 문제를 이해하고 해결하는 데 필요한 능력을 약화시킵니다. 우리는 다양한 정보를 자유롭게 접할 수 있는 환경을 조성해야 합니다.
# 사용자4: 일부 국가에서는 정부가 미디어와 표현의 자유를 억압하여 특정 관점만을 허용하는 경우가 있습니다. 이는 시민들이 다양한 정보를 접하고 비판적으로 사고할 기회를 제한합니다. 이러한 억압은 사회 전반에 걸쳐 창의성과 혁신을 저해하며, 장기적으로는 사회 발전을 방해합니다. 우리는 표현의 자유를 보호하고 다양한 목소리가 공존할 수 있는 사회를 만들어야 합니다.
# 현재 의견: 사용자1: 미국의 일부 주에서는 학교에서 인종, 성별, 성적 지향 등과 관련된 비판적 관점을 가르치는 것을 제한하는 정책이 시행되고 있습니다1. 이러한 검열은 학생들이 다양한 시각을 접하고 비판적으로 사고할 기회를 박탈하며, 이는 교육의 본질을 훼손합니다. 교육은 다양한 관점을 통해 학생들이 스스로 사고할 수 있도록 도와야 하며, 검열은 이러한 과정을 방해합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자2: 현대 교육 시스템에서는 표준화된 시험과 결과 중심의 교육이 강조되면서, 학생들의 비판적 사고 능력이 저해되고 있습니다3. 시험 준비에 집중하다 보면 창의적이고 비판적인 사고를 할 기회가 줄어들며, 이는 학생들이 사회 문제를 깊이 있게 이해하고 해결할 능력을 제한합니다. 교육은 단순한 지식 전달이 아닌, 학생들이 비판적으로 사고하고 문제를 해결할 수 있는 능력을 길러줘야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자3: 책과 자료에 대한 검열은 독자들의 비판적 사고를 저해합니다2. 특정 주제나 관점을 담고 있는 책이 금지되거나 제한될 때, 독자들은 다양한 시각을 접할 기회를 잃게 됩니다. 이는 사회가 복잡한 문제를 이해하고 해결하는 데 필요한 능력을 약화시킵니다. 우리는 다양한 정보를 자유롭게 접할 수 있는 환경을 조성해야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자4: 일부 국가에서는 정부가 미디어와 표현의 자유를 억압하여 특정 관점만을 허용하는 경우가 있습니다. 이는 시민들이 다양한 정보를 접하고 비판적으로 사고할 기회를 제한합니다. 이러한 억압은 사회 전반에 걸쳐 창의성과 혁신을 저해하며, 장기적으로는 사회 발전을 방해합니다. 우리는 표현의 자유를 보호하고 다양한 목소리가 공존할 수 있는 사회를 만들어야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
#
# 주제: 3. 소설에서는 사랑과 우정 같은 인간적 유대가 체제에 의해 파괴되는 모습을 보여줍니다. 현실에서는 어떤 경우에 이런 상황이 벌어질 수 있을까요? 이에 대한 여러분의 생각은 어떠한가요?
# 이 주제에 대해 의견을 작성해 주세요.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자1: 현대 사회에서 정치적 억압은 개인 간의 유대를 파괴할 수 있습니다. 독재 정권 하에서는 가족이나 친구들 간의 대화조차 감시될 수 있으며, 이는 서로에 대한 불신을 조장합니다. 예를 들어, 북한과 같은 국가에서는 주민들이 서로를 감시하도록 강요받아 가족 간의 신뢰가 무너질 수 있습니다. 이러한 환경에서는 진정한 사랑과 우정이 싹트기 어렵습니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자2: 경제적 불안정과 사회적 규범은 개인적 유대를 약화시킬 수 있습니다. 현대 사회에서 경제적 압박은 사람들로 하여금 사랑과 우정을 경제적 가치로 평가하게 만들 수 있습니다2. 이는 진정한 인간 관계보다는 물질적인 조건을 중시하게 하며, 결과적으로 인간적 유대가 약화됩니다. 우리는 경제적 조건에 구애받지 않고 진정한 관계를 형성할 수 있는 환경을 조성해야 합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자3: 기술 발전으로 인한 프라이버시 침해는 인간적 유대를 위협할 수 있습니다. 스마트폰과 소셜 미디어는 개인의 사생활을 노출시키고, 이는 관계의 신뢰성을 해칠 수 있습니다. 또한, 온라인 상에서의 감시는 사람들로 하여금 자신의 감정을 솔직하게 표현하는 것을 주저하게 만들며, 이는 관계의 깊이를 얕게 만듭니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 사용자4: 문화적 차이와 편견은 인간적 유대를 방해할 수 있습니다. 특정 문화나 종교가 다른 문화와의 교류를 제한하거나 금지할 때, 이는 사랑과 우정이 형성될 기회를 줄입니다. 예를 들어, 일부 지역에서는 종교나 인종이 다른 사람들과의 결혼이나 교제를 금지하여 개인 간의 자연스러운 유대를 막습니다. 이러한 편견을 극복하고 다양성을 존중하는 문화가 필요합니다.
# 사용자 입력 (형식: 사용자명: 의견, 종료 시 '종료' 입력): 종료
# 필터링된 의견:
# 사용자1: 현대 사회에서 정치적 억압은 개인 간의 유대를 파괴할 수 있습니다. 독재 정권 하에서는 가족이나 친구들 간의 대화조차 감시될 수 있으며, 이는 서로에 대한 불신을 조장합니다. 예를 들어, 북한과 같은 국가에서는 주민들이 서로를 감시하도록 강요받아 가족 간의 신뢰가 무너질 수 있습니다. 이러한 환경에서는 진정한 사랑과 우정이 싹트기 어렵습니다.
# 사용자2: 경제적 불안정과 사회적 규범은 개인적 유대를 약화시킬 수 있습니다. 현대 사회에서 경제적 압박은 사람들로 하여금 사랑과 우정을 경제적 가치로 평가하게 만들 수 있습니다2. 이는 진정한 인간 관계보다는 물질적인 조건을 중시하게 하며, 결과적으로 인간적 유대가 약화됩니다. 우리는 경제적 조건에 구애받지 않고 진정한 관계를 형성할 수 있는 환경을 조성해야 합니다.
# 사용자3: 기술 발전으로 인한 프라이버시 침해는 인간적 유대를 위협할 수 있습니다. 스마트폰과 소셜 미디어는 개인의 사생활을 노출시키고, 이는 관계의 신뢰성을 해칠 수 있습니다. 또한, 온라인 상에서의 감시는 사람들로 하여금 자신의 감정을 솔직하게 표현하는 것을 주저하게 만들며, 이는 관계의 깊이를 얕게 만듭니다.
# 사용자4: 문화적 차이와 편견은 인간적 유대를 방해할 수 있습니다. 특정 문화나 종교가 다른 문화와의 교류를 제한하거나 금지할 때, 이는 사랑과 우정이 형성될 기회를 줄입니다. 예를 들어, 일부 지역에서는 종교나 인종이 다른 사람들과의 결혼이나 교제를 금지하여 개인 간의 자연스러운 유대를 막습니다. 이러한 편견을 극복하고 다양성을 존중하는 문화가 필요합니다.
# 현재 의견: 사용자1: 현대 사회에서 정치적 억압은 개인 간의 유대를 파괴할 수 있습니다. 독재 정권 하에서는 가족이나 친구들 간의 대화조차 감시될 수 있으며, 이는 서로에 대한 불신을 조장합니다. 예를 들어, 북한과 같은 국가에서는 주민들이 서로를 감시하도록 강요받아 가족 간의 신뢰가 무너질 수 있습니다. 이러한 환경에서는 진정한 사랑과 우정이 싹트기 어렵습니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자2: 경제적 불안정과 사회적 규범은 개인적 유대를 약화시킬 수 있습니다. 현대 사회에서 경제적 압박은 사람들로 하여금 사랑과 우정을 경제적 가치로 평가하게 만들 수 있습니다2. 이는 진정한 인간 관계보다는 물질적인 조건을 중시하게 하며, 결과적으로 인간적 유대가 약화됩니다. 우리는 경제적 조건에 구애받지 않고 진정한 관계를 형성할 수 있는 환경을 조성해야 합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자3: 기술 발전으로 인한 프라이버시 침해는 인간적 유대를 위협할 수 있습니다. 스마트폰과 소셜 미디어는 개인의 사생활을 노출시키고, 이는 관계의 신뢰성을 해칠 수 있습니다. 또한, 온라인 상에서의 감시는 사람들로 하여금 자신의 감정을 솔직하게 표현하는 것을 주저하게 만들며, 이는 관계의 깊이를 얕게 만듭니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
# 현재 의견: 사용자4: 문화적 차이와 편견은 인간적 유대를 방해할 수 있습니다. 특정 문화나 종교가 다른 문화와의 교류를 제한하거나 금지할 때, 이는 사랑과 우정이 형성될 기회를 줄입니다. 예를 들어, 일부 지역에서는 종교나 인종이 다른 사람들과의 결혼이나 교제를 금지하여 개인 간의 자연스러운 유대를 막습니다. 이러한 편견을 극복하고 다양성을 존중하는 문화가 필요합니다.
# 💡이 의견에 대해 3분간 자유롭게 이야기를 나눠주세요
#
# ⏳ 자유토의 시간이 종료되었습니다.
# 다음 의견으로 넘어갑니다.
#
# 모임 내용을 요약합니다...
# 모임 요약:
# 주제 1 요약:
# "1984"에서 묘사된 개인의 사생활 침해는 현대 사회에서도 스마트폰, CCTV, 인터넷 등을 통해 일어나고 있다. 또한, 다양한 온라인 플랫폼과 서비스가 사용자 데이터를 상업적으로 활용하며, 이는 개인 정보의 유출과 사생활 침해를 초래한다. AI와 안면 인식 기술 역시 개인의 사생활을 침해하며, 정보를 왜곡하여 사고를 제한하는 현상이 관찰된다. 이에 따라 기술 발전과 함께 개인의 자유와 프라이버시를 보호하는 노력이 필요하다.
#
# 주제 2 요약:
# 비판적 사고 억압의 예로는 학교에서 특정 주제를 가르치는 것을 제한하는 정책, 표준화된 시험 중심의 교육 시스템, 책과 자료의 검열, 그리고 미디어와 표현의 자유를 억압하는 정부의 행동 등이 있다. 이러한 경우들은 다양한 정보에 접근하고 비판적으로 사고하는 기회를 제한하며, 이는 사회 발전을 방해한다. 따라서, 비판적 사고를 강조하고 다양한 목소리가 존재할 수 있는 사회를 만드는 노력이 필요하다.
#
# 주제 3 요약:
# 인간적 유대가 파괴되는 경우로는 정치적 억압으로 인한 불신, 경제적 불안정으로 인한 인간 관계의 약화, 기술 발전에 따른 프라이버시 침해, 그리고 문화적 차이와 편견 등이 있다. 이러한 요인들은 사랑과 우정이 형성되는 것을 방해하며, 인간적 유대를 약화시킨다. 이에 따라 경제적 조건에 구애받지 않는 관계 형성, 프라이버시 보호, 그리고 다양성을 존중하는 문화가 필요하다.
